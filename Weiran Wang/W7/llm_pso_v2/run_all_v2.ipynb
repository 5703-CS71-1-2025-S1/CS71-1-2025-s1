# %%
# !python main_pso_only.py
# Out:
# [PSO-Only] Best AUC = 0.7622
# Best Iteration = 10

# %%
# !python main_controller_v2.py
# Out:
# [Baseline PSO] Best AUC = 0.7714
# Best Iteration = 9
# [LLM+PSO] Best AUC = 0.7715
# Best Iteration = 10

# %%
# !python compare_auc_v2.py

# %%
from IPython.display import Image, display
display(Image("logs/auc_comparison_v2.png"))

# %%
# !python boxplot_compare_v2.py
# Out:
# C:\Users\aoshin\Desktop\5703\W7\llm_pso_v2\boxplot_compare_v2.py:24: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([data1, data2], labels=labels, patch_artist=True, showmeans=True)
